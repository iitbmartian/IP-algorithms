# %%
from IPython import display
display.clear_output()
 
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.1.18 🚀 Python-3.11.3 torch-2.2.1+cpu CPU (AMD Ryzen 7 6800H with Radeon Graphics)
# Setup complete ✅ (16 CPUs, 15.2 GB RAM, 138.1/227.5 GB disk)

# %%
from ultralytics import YOLO

# %%
model = YOLO('models/best.pt')

# %%
model.predict(source=0, show=True)
# Out:
# 1/1: 0... Success ✅ (inf frames of shape 640x480 at 30.00 FPS)
#
#
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# Saving runs\detect\predict\02\stage0_Conv_features.png... (16/16)
# Saving runs\detect\predict\02\stage1_Conv_features.png... (32/32)
# Saving runs\detect\predict\02\stage2_C2f_features.png... (32/32)
# Saving runs\detect\predict\02\stage3_Conv_features.png... (32/64)
# Saving runs\detect\predict\02\stage4_C2f_features.png... (32/64)
# Saving runs\detect\predict\02\stage5_Conv_features.png... (32/128)
# Saving runs\detect\predict\02\stage6_C2f_features.png... (32/128)
# Saving runs\detect\predict\02\stage7_Conv_features.png... (32/256)
# Saving runs\detect\predict\02\stage8_C2f_features.png... (32/256)
# Saving runs\detect\predict\02\stage9_SPPF_features.png... (32/256)
# Saving runs\detect\predict\02\stage10_Upsample_features.png... (32/256)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 model.predict(source=0, show=True)
#
# File c:\Users\PRODI\anaconda3\Lib\site-packages\ultralytics\engine\model.py:429, in Model.predict(self, source, stream, predictor, **kwargs)
#     427 if prompts and hasattr(self.predictor, "set_prompts"):  # for SAM-type models
#     428     self.predictor.set_prompts(prompts)
# --> 429 return self.predictor.predict_cli(source=source) if is_cli else self.predictor(source=source, stream=stream)
#
# File c:\Users\PRODI\anaconda3\Lib\site-packages\ultralytics\engine\predictor.py:204, in BasePredictor.__call__(self, source, model, stream, *args, **kwargs)
#     202     return self.stream_inference(source, model, *args, **kwargs)
#     203 else:
# --> 204     return list(self.stream_inference(source, model, *args, **kwargs))
#
# File c:\Users\PRODI\anaconda3\Lib\site-packages\torch\utils\_contextlib.py:35, in _wrap_generator.<locals>.generator_context(*args, **kwargs)
#      32 try:
#      33     # Issuing `None` to a generator fires it up
#      34     with ctx_factory():
# ---> 35         response = gen.send(None)
#      37     while True:
#      38         try:
#      39             # Forward the response to our caller and get its next request
#
# File c:\Users\PRODI\anaconda3\Lib\site-packages\ultralytics\engine\predictor.py:283, in BasePredictor.stream_inference(self, source, model, *args, **kwargs)
#     281 # Inference
#     282 with profilers[1]:
# --> 283     preds = self.inference(im, *args, **kwargs)
#     284     if self.args.embed:
#     285         yield from [preds] if isinstance(preds, torch.Tensor) else preds  # yield embedding tensors
#
# File c:\Users\PRODI\anaconda3\Lib\site-packages\ultralytics\engine\predictor.py:140, in BasePredictor.inference(self, im, *args, **kwargs)
#     134 """Runs inference on a given image using the specified model and arguments."""
#     135 visualize = (
#     136     increment_path(self.save_dir / Path(self.batch[0][0]).stem, mkdir=True)
#     137     if self.args.visualize and (not self.source_type.tensor)
#     138     else False
#     139 )
# --> 140 return self.model(im, augment=self.args.augment, visualize=visualize, embed=self.args.embed, *args, **kwargs)
#
# File c:\Users\PRODI\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File c:\Users\PRODI\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File c:\Users\PRODI\anaconda3\Lib\site-packages\ultralytics\nn\autobackend.py:384, in AutoBackend.forward(self, im, augment, visualize, embed)
#     381     im = im.permute(0, 2, 3, 1)  # torch BCHW to numpy BHWC shape(1,320,192,3)
#     383 if self.pt or self.nn_module:  # PyTorch
# --> 384     y = self.model(im, augment=augment, visualize=visualize, embed=embed)
#     385 elif self.jit:  # TorchScript
#     386     y = self.model(im)
#
# File c:\Users\PRODI\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File c:\Users\PRODI\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File c:\Users\PRODI\anaconda3\Lib\site-packages\ultralytics\nn\tasks.py:83, in BaseModel.forward(self, x, *args, **kwargs)
#      81 if isinstance(x, dict):  # for cases of training and validating while training.
#      82     return self.loss(x, *args, **kwargs)
# ---> 83 return self.predict(x, *args, **kwargs)
#
# File c:\Users\PRODI\anaconda3\Lib\site-packages\ultralytics\nn\tasks.py:101, in BaseModel.predict(self, x, profile, visualize, augment, embed)
#      99 if augment:
#     100     return self._predict_augment(x)
# --> 101 return self._predict_once(x, profile, visualize, embed)
#
# File c:\Users\PRODI\anaconda3\Lib\site-packages\ultralytics\nn\tasks.py:125, in BaseModel._predict_once(self, x, profile, visualize, embed)
#     123 y.append(x if m.i in self.save else None)  # save output
#     124 if visualize:
# --> 125     feature_visualization(x, m.type, m.i, save_dir=visualize)
#     126 if embed and m.i in embed:
#     127     embeddings.append(nn.functional.adaptive_avg_pool2d(x, (1, 1)).squeeze(-1).squeeze(-1))  # flatten
#
# File c:\Users\PRODI\anaconda3\Lib\site-packages\ultralytics\utils\plotting.py:1035, in feature_visualization(x, module_type, stage, n, save_dir)
#    1033 blocks = torch.chunk(x[0].cpu(), channels, dim=0)  # select batch index 0, block by channels
#    1034 n = min(n, channels)  # number of plots
# -> 1035 fig, ax = plt.subplots(math.ceil(n / 8), 8, tight_layout=True)  # 8 rows x n/8 cols
#    1036 ax = ax.ravel()
#    1037 plt.subplots_adjust(wspace=0.05, hspace=0.05)
#
# File c:\Users\PRODI\anaconda3\Lib\site-packages\matplotlib\pyplot.py:1502, in subplots(nrows, ncols, sharex, sharey, squeeze, width_ratios, height_ratios, subplot_kw, gridspec_kw, **fig_kw)
#    1358 """
#    1359 Create a figure and a set of subplots.
#    1360
#    (...)
#    1499
#    1500 """
#    1501 fig = figure(**fig_kw)
# -> 1502 axs = fig.subplots(nrows=nrows, ncols=ncols, sharex=sharex, sharey=sharey,
#    1503                    squeeze=squeeze, subplot_kw=subplot_kw,
#    1504                    gridspec_kw=gridspec_kw, height_ratios=height_ratios,
#    1505                    width_ratios=width_ratios)
#    1506 return fig, axs
#
# File c:\Users\PRODI\anaconda3\Lib\site-packages\matplotlib\figure.py:906, in FigureBase.subplots(self, nrows, ncols, sharex, sharey, squeeze, width_ratios, height_ratios, subplot_kw, gridspec_kw)
#     903     gridspec_kw['width_ratios'] = width_ratios
#     905 gs = self.add_gridspec(nrows, ncols, figure=self, **gridspec_kw)
# --> 906 axs = gs.subplots(sharex=sharex, sharey=sharey, squeeze=squeeze,
#     907                   subplot_kw=subplot_kw)
#     908 return axs
#
# File c:\Users\PRODI\anaconda3\Lib\site-packages\matplotlib\gridspec.py:299, in GridSpecBase.subplots(self, sharex, sharey, squeeze, subplot_kw)
#     297         subplot_kw["sharex"] = shared_with[sharex]
#     298         subplot_kw["sharey"] = shared_with[sharey]
# --> 299         axarr[row, col] = figure.add_subplot(
#     300             self[row, col], **subplot_kw)
#     302 # turn off redundant tick labeling
#     303 if sharex in ["col", "all"]:
#
# File c:\Users\PRODI\anaconda3\Lib\site-packages\matplotlib\figure.py:757, in FigureBase.add_subplot(self, *args, **kwargs)
#     754         args = tuple(map(int, str(args[0])))
#     755     projection_class, pkw = self._process_projection_requirements(
#     756         *args, **kwargs)
# --> 757     ax = projection_class(self, *args, **pkw)
#     758     key = (projection_class, pkw)
#     759 return self._add_axes_internal(ax, key)
#
# File c:\Users\PRODI\anaconda3\Lib\site-packages\matplotlib\axes\_base.py:675, in _AxesBase.__init__(self, fig, facecolor, frameon, sharex, sharey, label, xscale, yscale, box_aspect, *args, **kwargs)
#     672 self.spines = mspines.Spines.from_dict(self._gen_axes_spines())
#     674 # this call may differ for non-sep axes, e.g., polar
# --> 675 self._init_axis()
#     676 if facecolor is None:
#     677     facecolor = mpl.rcParams['axes.facecolor']
#
# File c:\Users\PRODI\anaconda3\Lib\site-packages\matplotlib\axes\_base.py:821, in _AxesBase._init_axis(self)
#     818 def _init_axis(self):
#     819     # This is moved out of __init__ because non-separable axes don't use it
#     820     self.xaxis = maxis.XAxis(self)
# --> 821     self.spines.bottom.register_axis(self.xaxis)
#     822     self.spines.top.register_axis(self.xaxis)
#     823     self.yaxis = maxis.YAxis(self)
#
# File c:\Users\PRODI\anaconda3\Lib\site-packages\matplotlib\spines.py:218, in Spine.register_axis(self, axis)
#     216 self.axis = axis
#     217 if self.axis is not None:
# --> 218     self.axis.clear()
#     219 self.stale = True
#
# File c:\Users\PRODI\anaconda3\Lib\site-packages\matplotlib\axis.py:879, in Axis.clear(self)
#     875 self.labelpad = mpl.rcParams['axes.labelpad']
#     877 self._init()
# --> 879 self._set_scale('linear')
#     881 # Clear the callback registry for this axis, or it may "leak"
#     882 self.callbacks = cbook.CallbackRegistry(signals=["units"])
#
# File c:\Users\PRODI\anaconda3\Lib\site-packages\matplotlib\axis.py:770, in Axis._set_scale(self, value, **kwargs)
#     768 else:
#     769     self._scale = value
# --> 770 self._scale.set_default_locators_and_formatters(self)
#     772 self.isDefault_majloc = True
#     773 self.isDefault_minloc = True
#
# File c:\Users\PRODI\anaconda3\Lib\site-packages\matplotlib\scale.py:105, in LinearScale.set_default_locators_and_formatters(self, axis)
#     103 def set_default_locators_and_formatters(self, axis):
#     104     # docstring inherited
# --> 105     axis.set_major_locator(AutoLocator())
#     106     axis.set_major_formatter(ScalarFormatter())
#     107     axis.set_minor_formatter(NullFormatter())
#
# File c:\Users\PRODI\anaconda3\Lib\site-packages\matplotlib\ticker.py:2900, in AutoLocator.__init__(self)
#    2898     nbins = 'auto'
#    2899     steps = [1, 2, 2.5, 5, 10]
# -> 2900 super().__init__(nbins=nbins, steps=steps)
#
# File c:\Users\PRODI\anaconda3\Lib\site-packages\matplotlib\ticker.py:2008, in MaxNLocator.__init__(self, nbins, **kwargs)
#    2006 if nbins is not None:
#    2007     kwargs['nbins'] = nbins
# -> 2008 self.set_params(**{**self.default_params, **kwargs})
#
# File c:\Users\PRODI\anaconda3\Lib\site-packages\matplotlib\ticker.py:2068, in MaxNLocator.set_params(self, **kwargs)
#    2066     else:
#    2067         self._steps = self._validate_steps(steps)
# -> 2068     self._extended_steps = self._staircase(self._steps)
#    2069 if 'integer' in kwargs:
#    2070     self._integer = kwargs.pop('integer')
#
# File c:\Users\PRODI\anaconda3\Lib\site-packages\matplotlib\ticker.py:2029, in MaxNLocator._staircase(steps)
#    2025 @staticmethod
#    2026 def _staircase(steps):
#    2027     # Make an extended staircase within which the needed step will be
#    2028     # found.  This is probably much larger than necessary.
# -> 2029     return np.concatenate([0.1 * steps[:-1], steps, [10 * steps[1]]])
#
# File <__array_function__ internals>:200, in concatenate(*args, **kwargs)
#
# KeyboardInterrupt:
